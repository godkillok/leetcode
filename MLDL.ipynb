# %% [markdown]
# 1.atten 和 tranformer
# https://blog.csdn.net/qq_41664845/article/details/84969266
# https://daiwk.github.io/posts/nlp-bert-code-annotated-framework.html
# https://www.cnblogs.com/robert-dlut/p/8638283.html

# %% [markdown]
# 2.CRF bi lstm (先看这个)
# https://www.cnblogs.com/createMoMo/p/7529885.html

# %% [markdown]
# 2.CRF,HMM
# https://www.cnblogs.com/hellochennan/p/6624509.html
#
# https://www.zhihu.com/question/35866596
#
# [VERTIBI](https://blog.csdn.net/ufv59to8/article/details/79350870)

# %% [markdown]
# 3.GBDT XGBOOST
#
# https://zhuanlan.zhihu.com/p/58269560?utm_source=wechat_session&utm_medium=social&utm_oi=849578657075855360

# %% [markdown]
# 4.SVM LR

# %% [markdown]
# 5.向后传播
#
# https://blog.csdn.net/yxiachan/article/details/81222174
#
# 前向传播（Forward propagation）
#
# Input:$$ a^{[l-1]}  $$
#
# Output：$$ a^{[l]} ， \rm cache(z^{[l]})  $$
#
#     公式：
#
#  $$ z^{[l]}= W^{[l]}\cdot a^{[l-1]}+b^{[l]}\\a^{[l]}=g^{[l]}(z^{[l]})  $$
#
#     向量化程序：
#
#  $$ Z^{[l]}=W^{[l]}\cdot A^{[l-1]}+b^{[l]}\\A^{[l]}=g^{[l]}(Z^{[l]})  $$
#
#
# **反向传播（Backward propagation）**
#
# Input：  $ da^{[l]}  $ 这个意思是d(cost)/da
#
# Output：  $ da^{[l-1]} ， dW^{[l]} ，db^{[l]}  $
#
#
# 所以  $ dz^{[l]}  $ 这个意思是$\dfrac{d(cost)}{dz}$ 而$dz$ 与$d(cost)$ 是没有直接关系，
# 因此需要借助a来弄，因为 $a^{[l]}=g^{[l]}(z^{[l]})$,因此$dz$就是$\dfrac{d(cost)}{dz}=\dfrac{d(cost)}{da}\dfrac{da}{dz}$
#
# 公式：
#
#  $$ dz^{[l]}=da^{[l]} * g^{[l]}{'}(z^{[l]})\\dW^{[l]}=dz^{[l]}\cdot a^{[l-1]}\\db^{[l]}=dz^{[l]}\\da^{[l-1]}=W^{[l]}{^T}\cdot dz^{[l]}  $$
# 将 $ da^{[l-1]}$ 代入 $dz^{[l]} $，有：
#
#  $$ dz^{[l]}=W^{[l+1]}{^T}\cdot dz^{[l+1]}* g^{[l]}{'}(z^{[l]})\\   $$
#
# 向量化程序：
#
#  $$ dZ^{[l]}=dA^{[l]} * g^{[l]}{'}(Z^{[l]})\\dW^{[l]}=\dfrac{1}{m}dZ^{[l]}\cdot A^{[l-1]}\\db^{[l]}=\dfrac{1}{m}np.sum(dZ^{[l]},axis=1,keepdims = True)\\dA^{[l-1]}=W^{[l]}{^T}\cdot dZ^{[l]} $$

# %% [markdown]
# 6.
#
# BP 向后传播
#
# CNN CONVEC  POOL
#
# [LSTM 的结构](https://blog.csdn.net/gzj_1101/article/details/79376798)

# %% [markdown]
# 7.LDA
#
# 一篇文章中的每个词可以是通过以一定的概率选择了某个主题（正如选择了爱情、亲情这样的主题一样），然后从这个主题当中又以一定的概率选择词语来进行表达，这样的过程就是一个生成模型
# ![%E5%9B%BE%E7%89%87.png](attachment:%E5%9B%BE%E7%89%87.png)
#
#
# https://blog.csdn.net/qq_27231343/article/details/51834959
#
# https://blog.csdn.net/u010159842/article/details/48637095

# %% [markdown]
# 8.几种常见的优化算法
#
# 就是在不同方向上，如果不长一致的话，但是可以看出它的上下波动很大，收敛的速度很慢。因此根据这些原因，有人提出了Momentum优化算法，这个是基于SGD的，简单理解，就是为了防止波动，取前几次波动的平均值当做这次的W。
#
# 而Momentum，RMSprop是很长时间来最经得住考研的优化算法，适合用于不同的深度学习结构。所以有人就有想法，何不将这俩的方法结合到一起呢？然后，pia ji一下，Adam问世了。全程Adaptive Moment Estimation。
#
#
# ![%E5%9B%BE%E7%89%87.png](attachment:%E5%9B%BE%E7%89%87.png)
#
# https://www.jianshu.com/p/548049548fb9
# https://blog.csdn.net/u012328159/article/details/80311892

# %% [markdown]
# 9.pointer network
#
# https://lianhaimiao.github.io/2018/08/21/Pointer-Network-%E7%9A%84%E4%B8%80%E4%BA%9B%E7%90%86%E8%A7%A3/
# https://zhuanlan.zhihu.com/p/30860157
